# %% [markdown]
# <a href="https://colab.research.google.com/github/moukouel/Notebooks/blob/main/DF_Lesson1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Section One - Working with Machine Learning
# The world around you is increasingly powered by machine learning, but you don’t know how to start. Here we help you get the toolbox for machine learning in Python in just 30 minutes.

# %% [markdown]
# # 1.1: Goals and variations in Machine Learning

# %%
# prompt: import pandas

import pandas as pd
# No further code needed as the provided text is just comments and does not require pandas operations.

# %%
import numpy as np

# %% [markdown]
# # 1.3: Exploring your data using pandas

# %%
# query
df = pd.DataFrame(np.random.rand(20, 5), columns=list('xyzwt'))
df
# Out:
#            x         y         z         w         t
# 0   0.282011  0.904503  0.923508  0.965907  0.515496
# 1   0.227652  0.226742  0.511916  0.564127  0.451314
# 2   0.540348  0.500658  0.771380  0.953494  0.585950
# 3   0.306070  0.988325  0.950694  0.855366  0.620728
# 4   0.656743  0.645665  0.931781  0.815236  0.363742
# 5   0.973736  0.330840  0.424183  0.097263  0.038468
# 6   0.685485  0.499008  0.769667  0.867449  0.818906
# 7   0.098907  0.506971  0.524490  0.225198  0.728602
# 8   0.018908  0.541869  0.585080  0.099268  0.252961
# 9   0.688955  0.083925  0.557158  0.787858  0.717933
# 10  0.516964  0.106147  0.873647  0.104814  0.332019
# 11  0.521007  0.527512  0.178999  0.746964  0.336266
# 12  0.602053  0.726743  0.113554  0.249764  0.981361
# 13  0.273151  0.109980  0.711616  0.274488  0.080197
# 14  0.356066  0.229384  0.157908  0.087189  0.774943
# 15  0.419247  0.153674  0.582483  0.560281  0.038288
# 16  0.397014  0.466790  0.897071  0.088518  0.011135
# 17  0.295425  0.454200  0.231918  0.392590  0.904674
# 18  0.850989  0.924764  0.476530  0.219898  0.334508
# 19  0.068198  0.923909  0.945532  0.071970  0.331370
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['x'].plot(kind='hist', bins=20, title='x')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['y'].plot(kind='hist', bins=20, title='y')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['z'].plot(kind='hist', bins=20, title='z')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['w'].plot(kind='hist', bins=20, title='w')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df.plot(kind='scatter', x='x', y='y', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df.plot(kind='scatter', x='y', y='z', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df.plot(kind='scatter', x='z', y='w', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df.plot(kind='scatter', x='w', y='t', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['t']
#   ys = series['x']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df.sort_values('t', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('t')
# _ = plt.ylabel('x')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['t']
#   ys = series['y']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df.sort_values('t', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('t')
# _ = plt.ylabel('y')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['t']
#   ys = series['z']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df.sort_values('t', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('t')
# _ = plt.ylabel('z')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['t']
#   ys = series['w']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df.sort_values('t', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('t')
# _ = plt.ylabel('w')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['x'].plot(kind='line', figsize=(8, 4), title='x')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df['y'].plot(kind='line', figsize=(8, 4), title='y')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df['z'].plot(kind='line', figsize=(8, 4), title='z')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df['w'].plot(kind='line', figsize=(8, 4), title='w')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
df.plot(kind='scatter', x='x', y='y', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# we can query the df like this
df[(df.x< df.y) & (df.y < df.z)]
# Out:
#            x         y         z         w         t
# 0   0.282011  0.904503  0.923508  0.965907  0.515496
# 7   0.098907  0.506971  0.524490  0.225198  0.728602
# 8   0.018908  0.541869  0.585080  0.099268  0.252961
# 16  0.397014  0.466790  0.897071  0.088518  0.011135
# 19  0.068198  0.923909  0.945532  0.071970  0.331370
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['x'].plot(kind='hist', bins=20, title='x')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['y'].plot(kind='hist', bins=20, title='y')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['z'].plot(kind='hist', bins=20, title='z')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['w'].plot(kind='hist', bins=20, title='w')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='x', y='y', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='y', y='z', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='z', y='w', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='w', y='t', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['t']
#   ys = series['x']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_8.sort_values('t', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('t')
# _ = plt.ylabel('x')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['t']
#   ys = series['y']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('t', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('t')
# _ = plt.ylabel('y')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['t']
#   ys = series['z']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('t', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('t')
# _ = plt.ylabel('z')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['t']
#   ys = series['w']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('t', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('t')
# _ = plt.ylabel('w')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['x'].plot(kind='line', figsize=(8, 4), title='x')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['y'].plot(kind='line', figsize=(8, 4), title='y')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['z'].plot(kind='line', figsize=(8, 4), title='z')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['w'].plot(kind='line', figsize=(8, 4), title='w')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_5.plot(kind='scatter', x='y', y='z', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# or, equivalently
df.query('(x < y) & (y < z)')
# Out:
#           x         y         z
# 3  0.106532  0.466499  0.604355
# 6  0.301034  0.329013  0.976976

# %%
# query based on the VALUE of the index
df.query('index > y > z')
# Out:
#           x         y         z
# 1  0.285711  0.888506  0.324758
# 2  0.151997  0.880747  0.027628
# 4  0.251896  0.560326  0.073755
# 7  0.395585  0.949703  0.710435

# %%
# using in and not in
df = pd.DataFrame({'a': list('aabbccddeeff'), 'b': list('aaaabbbbcccc')})
df
# Out:
#     a  b
# 0   a  a
# 1   a  a
# 2   b  a
# 3   b  a
# 4   c  b
# 5   c  b
# 6   d  b
# 7   d  b
# 8   e  c
# 9   e  c
# 10  f  c
# 11  f  c

# %%
df.query('a in b')
# Out:
#    a  b
# 0  a  a
# 1  a  a
# 2  b  a
# 3  b  a
# 4  c  b
# 5  c  b

# %%
df.query('a not in b')
# Out:
#     a  b
# 6   d  b
# 7   d  b
# 8   e  c
# 9   e  c
# 10  f  c
# 11  f  c

# %%
df.query('b == ["a", "b"]')
# Out:
#    a  b
# 0  a  a
# 1  a  a
# 2  b  a
# 3  b  a
# 4  c  b
# 5  c  b
# 6  d  b
# 7  d  b

# %%
# where
# DataFrame.where(cond, other=nan, inplace=False, axis=None,
#     level=None, errors='raise', try_cast=False, raise_on_error=None)

s = pd.Series(range(5))
s
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
# select a subset
s[s > 0]
# Out:
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
# select a subset, but retain the shape of the Series
s.where(s > 0)
# Out:
# 0    NaN
# 1    1.0
# 2    2.0
# 3    3.0
# 4    4.0
# dtype: float64

# %%
# similar, but different
s.mask(s > 0)
# Out:
# 0    0.0
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# dtype: float64
